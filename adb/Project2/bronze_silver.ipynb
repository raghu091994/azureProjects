# %%
# Create Silver managed table
spark.sql("CREATE SCHEMA IF NOT EXISTS adbrag.silver")

# %%
# %run ./01_customers_bronze_to_silver

# %%
# %run ./02_products_bronze_to_silver

# %%
# %run ./03_orders_bronze_to_silver

# %%
# %run ./04_sales_bronze_to_silver

# %%
# %run ./05_employees_bronze_to_silver
