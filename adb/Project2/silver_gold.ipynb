# %%
# Create Silver managed table
catalog_name = 'adbrag'
schema_name = 'gold'
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog_name}.{schema_name}")

# %% [markdown]
# #%run ./01_customers_silver_to_gold_scd1

# %%
# %run ./02_products_silver_to_gold

# %%
# %run ./03_orders_silver_to_gold

# %%
# %run ./04_sales_silver_to_gold

# %%
# %run ./05_employees_silver_to_gold
